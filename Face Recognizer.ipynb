# %%
# -*- coding: utf-8 -*-
import json
import cv2
from FacialTrain import Model

# %%
# Define a suitable class for face recognition.
class Face_recognition():
    # Open the constrast table , output a name according to the number of name.
    def __init__(self):
        with open('contrast_table', 'r') as f:
            self.contrast_table = json.loads(f.read())
            
        #Import the model and assign it to a class viariables.
        self.model = Model()
        
        # Load a trained model from a suitable path.
        self.model.load_model(file_path='./model')
        
        # Mark a face use a green frame.
        self.color = (0, 255, 0)

        # 捕获指定摄像头的实时视频流
        self.cap = cv2.VideoCapture(0)

        # Local storage path for face recognition classifiers.
        self.cascade_path = "haarcascade_frontalface_default.xml"

    def recongition(self):
        while True:
            # Read a frame picture
            ret, frame = self.cap.read()

            if ret is True:

                # Let the picture grey, which can reduce the complexity of process.
                frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            else:
                continue
                
            # Load the face claasifier.
            cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
            
            # Get the face use the detector.
            faceRects = cascade.detectMultiScale(frame_gray, scaleFactor=1.2, minNeighbors=3, minSize=(32, 32))
            if len(faceRects) > 0:
                for faceRect in faceRects:
                    # Assign the face data to 4 variables
                    x, y, w, h = faceRect

                     # Get the face picture
                    image = frame[y - 10: y + h + 10, x - 10: x + w + 10]
                    #print(image.shape)
                    
                    # Input image into face_predicye function.
                    probability, name_number = self.model.face_predict(image)
                    
                    # Use the return number to return a anme throught the constract table.
                    name = self.contrast_table[str(name_number)]

                    # print('name_number:', name_number)
                    # Specify the green frame, color and size.
                    cv2.rectangle(frame, (x - 10, y - 10), (x + w + 10, y + h + 10), self.color, thickness=2)

                    # Output name in window
                    cv2.putText(frame, name, (x + 30, y + 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)
                    # if probability > 0.7:
                    #     cv2.putText(frame, name, (x + 30, y + 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)
                    # else:
                    #     cv2.putText(frame, 'unknow', (x + 30, y + 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)

            cv2.imshow("face_recognition", frame)

            # Check if press any key after waiting 10s.
            k = cv2.waitKey(10)
            
            # Press Q to quit camera.
            if k & 0xFF == ord('q'):
                break

        # Release all windows and camera.
        self.cap.release()
        cv2.destroyAllWindows()


if __name__ == '__main__':
    fr = Face_recognition()
    fr.recongition()
# Out:
# result: [[0.96758884 0.01598931 0.01642182]] 0.96758884
# result: [[0.88770723 0.03695664 0.07533606]] 0.88770723
# result: [[0.9666646  0.02340424 0.00993125]] 0.9666646
# result: [[0.92656153 0.0604396  0.01299885]] 0.92656153
# result: [[0.7888113  0.1978252  0.01336347]] 0.7888113
# result: [[0.60175693 0.36366457 0.03457859]] 0.60175693
# result: [[0.60364306 0.36198983 0.03436708]] 0.60364306
# result: [[0.9390262  0.05949274 0.00148107]] 0.9390262
# result: [[0.8938368  0.09975942 0.0064038 ]] 0.8938368
# result: [[0.9332219  0.06477463 0.00200346]] 0.9332219
# result: [[0.92306286 0.0708765  0.0060607 ]] 0.92306286
# result: [[0.8618173  0.13522309 0.00295963]] 0.8618173
# result: [[9.3716335e-01 6.2219840e-02 6.1681011e-04]] 0.93716335
# result: [[9.0757579e-01 9.1781475e-02 6.4264605e-04]] 0.9075758
# result: [[0.85838395 0.1407057  0.00091032]] 0.85838395
# result: [[9.1516078e-01 8.4267884e-02 5.7127984e-04]] 0.9151608
# result: [[0.7122111  0.28105465 0.00673431]] 0.7122111
# result: [[0.77108294 0.22428037 0.00463676]] 0.77108294
# result: [[9.5336866e-01 4.6448022e-02 1.8333564e-04]] 0.95336866
# result: [[9.1009974e-01 8.9319669e-02 5.8050203e-04]] 0.91009974
# result: [[9.6421015e-01 3.5658836e-02 1.3102868e-04]] 0.96421015
# result: [[0.75096166 0.24411081 0.00492757]] 0.75096166
# result: [[0.6105867  0.38381457 0.00559872]] 0.6105867
# result: [[0.6845695  0.3087508  0.00667981]] 0.6845695
# result: [[0.8582533  0.13678977 0.00495686]] 0.8582533
# result: [[9.2574000e-01 7.3357210e-02 9.0276316e-04]] 0.92574
# result: [[0.8388392  0.15998721 0.00117372]] 0.8388392
# result: [[9.506110e-01 4.928042e-02 1.085081e-04]] 0.950611
# result: [[0.88832855 0.11038358 0.00128787]] 0.88832855
# result: [[8.8945431e-01 1.1006772e-01 4.7798763e-04]] 0.8894543
# result: [[8.4187311e-01 1.5758403e-01 5.4280995e-04]] 0.8418731
# result: [[9.6595478e-01 3.4020822e-02 2.4369159e-05]] 0.9659548
# result: [[8.9838761e-01 1.0133900e-01 2.7339486e-04]] 0.8983876
# result: [[9.1675878e-01 8.3062515e-02 1.7866571e-04]] 0.9167588
# result: [[9.1076499e-01 8.9106411e-02 1.2864475e-04]] 0.910765
# result: [[0.7017669  0.29681012 0.00142289]] 0.7017669
# result: [[9.6406865e-01 3.5917025e-02 1.4316842e-05]] 0.96406865
# result: [[9.4622016e-01 5.3737339e-02 4.2573407e-05]] 0.94622016
# result: [[7.9422802e-01 2.0524225e-01 5.2971183e-04]] 0.794228
# result: [[0.5234061  0.47190788 0.00468612]] 0.5234061
# result: [[0.69657624 0.21071918 0.0927046 ]] 0.69657624
# result: [[5.1721127e-06 9.9976009e-01 2.3483843e-04]] 0.9997601
# result: [[0.75550395 0.2010444  0.04345167]] 0.75550395
# result: [[1.2678337e-05 9.9916768e-01 8.1965694e-04]] 0.9991677
# result: [[0.6986152  0.24329853 0.05808629]] 0.6986152
# result: [[1.0036220e-05 9.9845791e-01 1.5321115e-03]] 0.9984579
# result: [[0.7619865  0.22179137 0.0162221 ]] 0.7619865
# result: [[8.2539973e-06 9.9820304e-01 1.7887007e-03]] 0.99820304
# result: [[0.77969825 0.2001395  0.02016232]] 0.77969825
# result: [[1.0675483e-05 9.9807215e-01 1.9171665e-03]] 0.99807215
# result: [[0.8689486  0.09401604 0.03703535]] 0.8689486
# result: [[0.9063854  0.08452142 0.00909313]] 0.9063854
# result: [[1.02097365e-05 9.98507321e-01 1.48235774e-03]] 0.9985073
# result: [[0.85562164 0.13094038 0.0134379 ]] 0.85562164
# result: [[4.4666890e-06 9.9861884e-01 1.3766180e-03]] 0.99861884
# result: [[0.7786853  0.2040643  0.01725053]] 0.7786853
# result: [[1.5693387e-05 9.9772531e-01 2.2589527e-03]] 0.9977253
# result: [[0.8149635  0.16314758 0.02188887]] 0.8149635
# result: [[1.6209793e-05 9.9756420e-01 2.4196140e-03]] 0.9975642
# result: [[0.7280143  0.25462833 0.01735738]] 0.7280143
# result: [[3.9473431e-05 9.9497753e-01 4.9829376e-03]] 0.99497753
# result: [[0.6921173  0.27281538 0.03506741]] 0.6921173
# result: [[9.6488075e-06 9.9844801e-01 1.5423709e-03]] 0.998448
# result: [[0.8722777  0.11301317 0.01470917]] 0.8722777
# result: [[8.4894873e-06 9.9984515e-01 1.4639040e-04]] 0.99984515
# result: [[0.62332034 0.02704065 0.34963906]] 0.62332034
# result: [[0.87992895 0.05031188 0.06975924]] 0.87992895
# result: [[0.9039449  0.04240888 0.05364623]] 0.9039449
# result: [[0.9575043  0.02841703 0.0140787 ]] 0.9575043
# result: [[0.8809624  0.04639769 0.07264002]] 0.8809624
# result: [[0.968828   0.01221034 0.01896169]] 0.968828
# result: [[0.908715   0.00872742 0.08255762]] 0.908715
# result: [[0.6877155  0.00478975 0.30749482]] 0.6877155
# result: [[0.82117593 0.00200497 0.17681916]] 0.82117593
# result: [[0.5236166  0.00879394 0.46758944]] 0.5236166
# result: [[0.39401773 0.01146194 0.59452033]] 0.59452033
# result: [[0.3970008  0.00983239 0.59316677]] 0.59316677
# result: [[0.41195545 0.00896401 0.5790805 ]] 0.5790805
# result: [[0.22928502 0.00705685 0.76365817]] 0.76365817
# result: [[0.169032   0.00590024 0.8250678 ]] 0.8250678
# result: [[0.7706014  0.00631054 0.22308804]] 0.7706014
# result: [[0.9123331  0.00459981 0.08306709]] 0.9123331
# result: [[0.8978891  0.00617291 0.095938  ]] 0.8978891
# result: [[0.6667125  0.00729238 0.3259951 ]] 0.6667125
# result: [[0.85531795 0.00750501 0.13717707]] 0.85531795
# result: [[0.7561111  0.00730022 0.23658866]] 0.7561111
# result: [[0.8383686  0.0067008  0.15493065]] 0.8383686
# result: [[0.95840955 0.00827997 0.03331043]] 0.95840955
# result: [[0.90510184 0.01485571 0.08004243]] 0.90510184
# result: [[0.9476681  0.01105572 0.04127627]] 0.9476681
# result: [[0.7813746  0.01821596 0.2004095 ]] 0.7813746
# result: [[0.8157935  0.01614957 0.16805694]] 0.8157935
# result: [[0.721126   0.02523657 0.2536375 ]] 0.721126
# result: [[0.8739811  0.01242574 0.11359315]] 0.8739811
# result: [[0.82927924 0.01340988 0.1573109 ]] 0.82927924
# result: [[0.93441814 0.00575775 0.05982418]] 0.93441814
# result: [[0.8431465  0.01067487 0.14617863]] 0.8431465
# result: [[0.92862207 0.00568847 0.06568949]] 0.92862207
# result: [[0.85397965 0.01655598 0.12946437]] 0.85397965
# result: [[0.8480304  0.0158897  0.13607995]] 0.8480304
# result: [[0.876349   0.0088502  0.11480079]] 0.876349
# result: [[0.90510136 0.00512955 0.08976917]] 0.90510136
# result: [[0.73139685 0.01142255 0.25718054]] 0.73139685
# result: [[0.86520773 0.00424037 0.13055192]] 0.86520773
# result: [[0.8122096  0.00480461 0.1829858 ]] 0.8122096
# result: [[0.772925   0.00537977 0.22169517]] 0.772925
# result: [[0.7447908  0.00535079 0.2498584 ]] 0.7447908
# result: [[0.6298443  0.00677437 0.3633813 ]] 0.6298443
# result: [[0.60841006 0.00499257 0.38659734]] 0.60841006
# result: [[0.8632754  0.00241371 0.13431086]] 0.8632754
# result: [[0.88908446 0.00233297 0.10858249]] 0.88908446
# result: [[0.8878929  0.0013941  0.11071302]] 0.8878929
# result: [[8.618753e-01 7.149910e-04 1.374097e-01]] 0.8618753
# result: [[0.85339576 0.00093213 0.14567208]] 0.85339576
# result: [[9.3025452e-01 7.5677520e-04 6.8988815e-02]] 0.9302545
# result: [[9.6103185e-01 1.8796825e-04 3.8780160e-02]] 0.96103185
# result: [[0.8412961  0.00088569 0.15781827]] 0.8412961
# result: [[0.8348139  0.00267021 0.16251588]] 0.8348139
# result: [[0.92346764 0.00149482 0.07503758]] 0.92346764
# result: [[0.9229481  0.00132326 0.07572867]] 0.9229481
# result: [[0.790086   0.00219141 0.20772262]] 0.790086
# result: [[0.7631123  0.00294449 0.23394322]] 0.7631123
# result: [[0.7198711  0.0025376  0.27759135]] 0.7198711
# result: [[0.7881495  0.0015736  0.21027693]] 0.7881495
# result: [[0.7889176  0.00185457 0.20922779]] 0.7889176
# result: [[9.1787815e-01 6.8820902e-04 8.1433617e-02]] 0.91787815
# result: [[0.7451673  0.00283122 0.2520014 ]] 0.7451673
# result: [[0.96090287 0.00459378 0.03450339]] 0.96090287
# result: [[4.3963564e-06 9.9994993e-01 4.5665052e-05]] 0.99994993
# result: [[0.9535304  0.01204413 0.03442551]] 0.9535304
# result: [[5.2093812e-05 9.7043431e-01 2.9513594e-02]] 0.9704343
# result: [[0.9074976  0.06503475 0.02746763]] 0.9074976
# result: [[8.5083529e-06 9.7538757e-01 2.4603963e-02]] 0.9753876
# result: [[0.9683497  0.01473062 0.01691975]] 0.9683497
# result: [[1.2151175e-05 9.7550189e-01 2.4486031e-02]] 0.9755019
# result: [[0.95534885 0.01982453 0.02482652]] 0.95534885
# result: [[2.0258125e-05 9.6892345e-01 3.1056270e-02]] 0.96892345
# result: [[0.952148   0.01933969 0.02851233]] 0.952148
# result: [[1.7180952e-05 9.4840497e-01 5.1577788e-02]] 0.94840497
# result: [[0.9182339  0.01876154 0.06300461]] 0.9182339
# result: [[8.5865231e-06 9.4742852e-01 5.2562933e-02]] 0.9474285
# result: [[0.8996043  0.02995297 0.07044267]] 0.8996043
# result: [[8.0664413e-06 9.1013384e-01 8.9858152e-02]] 0.91013384
# result: [[0.7895758  0.10059015 0.10983399]] 0.7895758
# result: [[8.5648771e-06 9.0109134e-01 9.8900020e-02]] 0.90109134
# result: [[0.04585551 0.24270315 0.7114413 ]] 0.7114413
# result: [[3.2847447e-06 9.5906842e-01 4.0928230e-02]] 0.9590684
# result: [[9.9555570e-01 4.0530944e-03 3.9115915e-04]] 0.9955557
# result: [[9.9722642e-01 2.5634631e-03 2.1007567e-04]] 0.9972264
# result: [[0.9581612  0.03501543 0.0068234 ]] 0.9581612
# result: [[7.9728661e-06 9.2478275e-01 7.5209312e-02]] 0.92478275
# result: [[9.8892003e-01 1.0709501e-02 3.7050049e-04]] 0.98892003
# result: [[9.9369264e-01 5.9644356e-03 3.4289469e-04]] 0.99369264
# result: [[0.04133398 0.6937581  0.26490796]] 0.6937581
# result: [[9.9307418e-01 6.5433816e-03 3.8235643e-04]] 0.9930742
# result: [[9.88216341e-01 1.12621095e-02 5.21501119e-04]] 0.98821634
# result: [[3.4786628e-06 9.5546728e-01 4.4529222e-02]] 0.9554673
# result: [[9.9510527e-01 4.4874470e-03 4.0723351e-04]] 0.99510527
# result: [[6.7356445e-06 9.3456918e-01 6.5424159e-02]] 0.9345692
# result: [[9.9472398e-01 5.0795134e-03 1.9644285e-04]] 0.994724
# result: [[9.8333341e-01 1.6332049e-02 3.3460042e-04]] 0.9833334
# result: [[9.8218614e-01 1.7061798e-02 7.5201492e-04]] 0.98218614
# result: [[0.97705805 0.02123263 0.00170937]] 0.97705805
# result: [[0.91775346 0.0755839  0.0066626 ]] 0.91775346
# result: [[9.8925227e-01 1.0087346e-02 6.6044647e-04]] 0.98925227
# result: [[9.8540050e-01 1.3917369e-02 6.8208412e-04]] 0.9854005
# result: [[8.7232611e-06 8.3968723e-01 1.6030411e-01]] 0.8396872
# result: [[0.9921693  0.00645937 0.00137124]] 0.9921693
# result: [[9.9109626e-01 8.0766995e-03 8.2707650e-04]] 0.99109626
# result: [[9.9531567e-01 4.3175826e-03 3.6674761e-04]] 0.9953157
# result: [[9.9254733e-01 6.8421094e-03 6.1056262e-04]] 0.99254733
# result: [[9.8940772e-01 1.0109832e-02 4.8248970e-04]] 0.9894077
# result: [[9.9224687e-01 7.3104585e-03 4.4264225e-04]] 0.99224687
# result: [[9.8449206e-01 1.4605332e-02 9.0257538e-04]] 0.98449206
# result: [[9.9282348e-01 6.6249645e-03 5.5152300e-04]] 0.9928235
# result: [[9.9486017e-01 4.7957813e-03 3.4402273e-04]] 0.9948602
# result: [[0.9574444  0.0388527  0.00370298]] 0.9574444
# result: [[9.9349397e-01 6.0053933e-03 5.0059950e-04]] 0.993494
# result: [[0.97332406 0.02442236 0.00225365]] 0.97332406
# result: [[9.8760766e-01 1.1872101e-02 5.2021997e-04]] 0.98760766
# result: [[0.9852099  0.01302193 0.00176816]] 0.9852099
