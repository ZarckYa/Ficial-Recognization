# %%
#Import useful libraries
import json
import os
import numpy as np
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras import utils
from LoadFaceData import read_path, resize_image, IMAGE_SIZE, load_dataset

# %%
# PCA processing of face data, retaining 100-dimensional features
n_components =150
Pre_names = []
counter = 0
right_counter = 0
test_frame_gray = []
Predictresult = []
#Read the face pictures from our path
Testfaceimages, Test_labels= read_path("D:\Limerick course year 4\AI & FYP\Conda Jupyter notebook\My AI Folder\FYP\Facial Recognization By RNN\Test data\Jufeng Yang")

#transfer the labels list in to data
facelabel = np.array(Test_labels)

#Get the number of face, which is depended by number the pictures files
labels1 = list(set(facelabel))
face_num = len(labels1)

# Store the test name into a dic called constrast_table. 
num = [i for i in range(face_num)]
contrast_table_Test = dict(zip(num, labels1))
with open('contrast_table_Test', 'w') as f:
    f.write(json.dumps(contrast_table_Test))

for face_image in Testfaceimages:
    test_frame_gray.append(cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY))
test_frame_gray = np.array(test_frame_gray)
Testfaceimage = test_frame_gray.reshape(-1, IMAGE_SIZE*IMAGE_SIZE)

#print(Testfaceimage.shape)

with open('contrast_table_Test', 'r') as f:
            contrast_table = json.loads(f.read())

# Training for PCA
pca = PCA(n_components=n_components, svd_solver='randomized',
          whiten=True, random_state=42).fit(Testfaceimage)

Test_face = pca.transform(Testfaceimage)

load_SVM = joblib.load("my_SVM_model.m")

Predictresult = load_SVM.predict(Test_face)

print(Predictresult)
for i in Predictresult:
    counter += 1
    if i == "Jufeng Yang":
        right_counter += 1
print("Accuracy:", right_counter/counter)
# Out:
# ['Jufeng Yang' 'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Xingda Zhou' 'Xingda Zhou'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Xingda Zhou' 'Xingda Zhou' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang' 'Jufeng Yang'
#  'Jufeng Yang' 'Xingda Zhou' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jiahao Wang' 'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Xingda Zhou' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Xingda Zhou' 'Xingda Zhou' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Xingda Zhou' 'Xingda Zhou' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang' 'Jiahao Wang' 'Jufeng Yang'
#  'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang'
#  'Jiahao Wang' 'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang' 'Jiahao Wang' 'Jiahao Wang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jiahao Wang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang'
#  'Jufeng Yang' 'Jufeng Yang' 'Jufeng Yang']
# Accuracy: 0.868421052631579
