# %%
import matplotlib.pyplot as plt

# %%
x = [20, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 145, 150, 151];
y = [0.5686, 0.5490, 0.6471, 0.7424, 0.7189, 0.7450, 0.7582, 0.7974, 
     0.8105, 0.8562, 0.8758, 0.9020, 0.9085, 0.9085, 0.9085, 0.9085];
plt.plot(x, y, label = "Accuracy varies with component parameter.")
plt.xlabel("component parameter")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
